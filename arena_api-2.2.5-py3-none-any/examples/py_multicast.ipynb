# %%
# -----------------------------------------------------------------------------
# Copyright (c) 2022, Lucid Vision Labs, Inc.
#
# THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND,
# EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES
# OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND
# NONINFRINGEMENT. IN NO EVENT SHALL THE AUTHORS OR COPYRIGHT HOLDERS
# BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN
# ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN
# CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN
# THE SOFTWARE.
# -----------------------------------------------------------------------------

# %%
import time
from arena_api.system import system
from datetime import datetime

NUM_SECONDS = 10
TIMEOUT_MILLISEC = 2000

# %%
'''
Multicast
    This example demonstrates multicasting from the master's perspective.
    Multicasting allows for the streaming of images and events to multiple
    destinations. Multicasting requires nearly the same steps for both
    masters and listeners. The only difference, as seen below, is that
    device features can only be set by the master.
'''
# Out:
# "\nMulticast\n    This example demonstrates multicasting from the master's perspective.\n    Multicasting allows for the streaming of images and events to multiple\n    destinations. Multicasting requires nearly the same steps for both\n    masters and listeners. The only difference, as seen below, is that\n    device features can only be set by the master.\n"

# %%
"""
This function waits for the user to connect a device before raising
an exception
"""

tries = 0
tries_max = 6
sleep_time_secs = 10
while tries < tries_max:  # Wait for device for 60 seconds
    devices = system.create_device()
    if not devices:
        print(
            f'Try {tries+1} of {tries_max}: waiting for {sleep_time_secs} '
            f'secs for a device to be connected!')
        for sec_count in range(sleep_time_secs):
            time.sleep(1)
            print(f'{sec_count + 1 } seconds passed ',
                  '.' * sec_count, end='\r')
        tries += 1
    else:
        print(f'Created {len(devices)} device(s)')
        device = devices[0]
        break
else:
    raise Exception(f'No device found! Please connect a device and run '
                    f'the example again.')
# Out:
# Created 1 device(s)

# %%
'''
Enable multicast and configure device
    Multicast must be enabled on both the master and listener. A small
    number of transport layer features will remain writable even
    though a device's access mode might be read-only.
'''
print('Enable multicast')
device.tl_stream_nodemap['StreamMulticastEnable'].value = True

'''
Prepare settings on master, not on listener
    Device features must be set on the master rather than the listener.
    This is because the listener is opened with a read-only access mode.
'''
device_access_status = device.tl_device_nodemap['DeviceAccessStatus'].value

# Master
if device_access_status == 'ReadWrite':

    print('Host streaming as "master"')

    # Get node values that will be changed in order to return their values
    # at the end of the example
    acquisition_mode_initial = device.nodemap['AcquisitionMode'].value

    # Set acquisition mode
    print('Set acquisition mode to "Continuous"')

    device.nodemap['AcquisitionMode'].value = 'Continuous'

    # Enable stream auto negotiate packet size
    device.tl_stream_nodemap['StreamAutoNegotiatePacketSize'].value = True

    # Enable stream packet resend
    device.tl_stream_nodemap['StreamPacketResendEnable'].value = True

# Listener
else:
    print('Host streaming as "listener"\n')
# Out:
# Enable multicast
# Host streaming as "master"
# Set acquisition mode to "Continuous"

# %%
# Define start and latest time for timed image acquisition
start_time = datetime.now()
latest_time = datetime.now()

# Start stream
with device.start_stream():

    # Define image count to detect if all images are not received
    image_count = 0
    unreceived_image_count = 0

    print(f'Stream started')

    while (latest_time - start_time).total_seconds() < NUM_SECONDS:

        # update time
        latest_time = datetime.now()

        try:
            image_count = image_count + 1

            # 'Device.get_buffer()' with no arguments returns
            #  only one buffer
            buffer = device.get_buffer(timeout=TIMEOUT_MILLISEC)

            # Print some info about the image in the buffer
            #   Using the frame ID and timestamp allows for the comparison
            #   of images between multiple hosts.
            print(f'\t\tImage retrieved ('
                  f'frame ID = {buffer.frame_id}, '
                  f'timestamp (ns) = {buffer.timestamp_ns}) and requeue')

        except(TimeoutError):
            print(f'\t\tNo image received')
            unreceived_image_count = unreceived_image_count + 1
            continue

        # Requeue the image buffer
        device.requeue_buffer(buffer)

if (unreceived_image_count == image_count):
    print(f'\nNo images were received, this can be caused by firewall, vpn settings or firmware\n')
    print(f'Please add python application to firewall exception')

# Return node to its initial value
if (device_access_status == "ReadWrite"):
    device.nodemap['AcquisitionMode'].value = acquisition_mode_initial

system.destroy_device()
# Out:
# Stream started
# 		Image retrieved (frame ID = 1, timestamp (ns) = 91403582074112) and requeue
# 		Image retrieved (frame ID = 2, timestamp (ns) = 91403604733712) and requeue
# 		Image retrieved (frame ID = 3, timestamp (ns) = 91403645717312) and requeue
# 		Image retrieved (frame ID = 4, timestamp (ns) = 91403705024912) and requeue
# 		Image retrieved (frame ID = 5, timestamp (ns) = 91403746008312) and requeue
# 		Image retrieved (frame ID = 6, timestamp (ns) = 91403786991912) and requeue
# 		Image retrieved (frame ID = 7, timestamp (ns) = 91403827975512) and requeue
# 		Image retrieved (frame ID = 8, timestamp (ns) = 91403868959112) and requeue
# 		Image retrieved (frame ID = 9, timestamp (ns) = 91403909942712) and requeue
# 		Image retrieved (frame ID = 10, timestamp (ns) = 91403950926312) and requeue
# 		Image retrieved (frame ID = 11, timestamp (ns) = 91403991909912) and requeue
# 		Image retrieved (frame ID = 12, timestamp (ns) = 91404032893312) and requeue
# 		Image retrieved (frame ID = 13, timestamp (ns) = 91404073876912) and requeue
# 		Image retrieved (frame ID = 14, timestamp (ns) = 91404114860512) and requeue
# 		Image retrieved (frame ID = 15, timestamp (ns) = 91404155844112) and requeue
# 		Image retrieved (frame ID = 16, timestamp (ns) = 91404196827712) and requeue
# 		Image retrieved (frame ID = 17, timestamp (ns) = 91404237811312) and requeue
# 		Image retrieved (frame ID = 18, timestamp (ns) = 91404278794712) and requeue
# 		Image retrieved (frame ID = 19, timestamp (ns) = 91404319778312) and requeue
# 		Image retrieved (frame ID = 20, timestamp (ns) = 91404360761912) and requeue
# 		Image retrieved (frame ID = 21, timestamp (ns) = 91404401745512) and requeue
# 		Image retrieved (frame ID = 22, timestamp (ns) = 91404442729112) and requeue
# 		Image retrieved (frame ID = 23, timestamp (ns) = 91404483712712) and requeue
# 		Image retrieved (frame ID = 24, timestamp (ns) = 91404524696112) and requeue
# 		Image retrieved (frame ID = 25, timestamp (ns) = 91404565679712) and requeue
# 		Image retrieved (frame ID = 26, timestamp (ns) = 91404606663312) and requeue
# 		Image retrieved (frame ID = 27, timestamp (ns) = 91404647646912) and requeue
# 		Image retrieved (frame ID = 28, timestamp (ns) = 91404688630512) and requeue
# 		Image retrieved (frame ID = 29, timestamp (ns) = 91404729614112) and requeue
# 		Image retrieved (frame ID = 30, timestamp (ns) = 91404770597712) and requeue
# 		Image retrieved (frame ID = 31, timestamp (ns) = 91404811581112) and requeue
# 		Image retrieved (frame ID = 32, timestamp (ns) = 91404852564712) and requeue
# 		Image retrieved (frame ID = 33, timestamp (ns) = 91404893548312) and requeue
# 		Image retrieved (frame ID = 34, timestamp (ns) = 91404934531912) and requeue
# 		Image retrieved (frame ID = 35, timestamp (ns) = 91404975515512) and requeue
# 		Image retrieved (frame ID = 36, timestamp (ns) = 91405016499112) and requeue
# 		Image retrieved (frame ID = 37, timestamp (ns) = 91405057482512) and requeue
# 		Image retrieved (frame ID = 38, timestamp (ns) = 91405098466112) and requeue
# 		Image retrieved (frame ID = 39, timestamp (ns) = 91405139449712) and requeue
# 		Image retrieved (frame ID = 40, timestamp (ns) = 91405180433312) and requeue
# 		Image retrieved (frame ID = 41, timestamp (ns) = 91405221416912) and requeue
# 		Image retrieved (frame ID = 42, timestamp (ns) = 91405262400512) and requeue
# 		Image retrieved (frame ID = 43, timestamp (ns) = 91405303384112) and requeue
# 		Image retrieved (frame ID = 44, timestamp (ns) = 91405344367512) and requeue
# 		Image retrieved (frame ID = 45, timestamp (ns) = 91405385351112) and requeue
# 		Image retrieved (frame ID = 46, timestamp (ns) = 91405426334712) and requeue
# 		Image retrieved (frame ID = 47, timestamp (ns) = 91405467318312) and requeue
# 		Image retrieved (frame ID = 48, timestamp (ns) = 91405508301912) and requeue
# 		Image retrieved (frame ID = 49, timestamp (ns) = 91405549285512) and requeue
# 		Image retrieved (frame ID = 50, timestamp (ns) = 91405590268912) and requeue
# 		Image retrieved (frame ID = 51, timestamp (ns) = 91405631252512) and requeue
# 		Image retrieved (frame ID = 52, timestamp (ns) = 91405672236112) and requeue
# 		Image retrieved (frame ID = 53, timestamp (ns) = 91405713219712) and requeue
# 		Image retrieved (frame ID = 54, timestamp (ns) = 91405754203312) and requeue
# 		Image retrieved (frame ID = 55, timestamp (ns) = 91405795186912) and requeue
# 		Image retrieved (frame ID = 56, timestamp (ns) = 91405836170312) and requeue
# 		Image retrieved (frame ID = 57, timestamp (ns) = 91405877153912) and requeue
# 		Image retrieved (frame ID = 58, timestamp (ns) = 91405918137512) and requeue
# 		Image retrieved (frame ID = 59, timestamp (ns) = 91405959121112) and requeue
# 		Image retrieved (frame ID = 60, timestamp (ns) = 91406000104712) and requeue
# 		Image retrieved (frame ID = 61, timestamp (ns) = 91406041088312) and requeue
# 		Image retrieved (frame ID = 62, timestamp (ns) = 91406082071912) and requeue
# 		Image retrieved (frame ID = 63, timestamp (ns) = 91406123055312) and requeue
# 		Image retrieved (frame ID = 64, timestamp (ns) = 91406164038912) and requeue
# 		Image retrieved (frame ID = 65, timestamp (ns) = 91406205022512) and requeue
# 		Image retrieved (frame ID = 66, timestamp (ns) = 91406246006112) and requeue
# 		Image retrieved (frame ID = 67, timestamp (ns) = 91406286989712) and requeue
# 		Image retrieved (frame ID = 68, timestamp (ns) = 91406327973312) and requeue
# 		Image retrieved (frame ID = 69, timestamp (ns) = 91406368956712) and requeue
# 		Image retrieved (frame ID = 70, timestamp (ns) = 91406409940312) and requeue
# 		Image retrieved (frame ID = 71, timestamp (ns) = 91406450923912) and requeue
# 		Image retrieved (frame ID = 72, timestamp (ns) = 91406491907512) and requeue
# 		Image retrieved (frame ID = 73, timestamp (ns) = 91406532891112) and requeue
# 		Image retrieved (frame ID = 74, timestamp (ns) = 91406573874712) and requeue
# 		Image retrieved (frame ID = 75, timestamp (ns) = 91406614858312) and requeue
# 		Image retrieved (frame ID = 76, timestamp (ns) = 91406655841712) and requeue
# 		Image retrieved (frame ID = 77, timestamp (ns) = 91406696825312) and requeue
# 		Image retrieved (frame ID = 78, timestamp (ns) = 91406737808912) and requeue
# 		Image retrieved (frame ID = 79, timestamp (ns) = 91406778792512) and requeue
# 		Image retrieved (frame ID = 80, timestamp (ns) = 91406819776112) and requeue
# 		Image retrieved (frame ID = 81, timestamp (ns) = 91406860759712) and requeue
# 		Image retrieved (frame ID = 82, timestamp (ns) = 91406901743112) and requeue
# 		Image retrieved (frame ID = 83, timestamp (ns) = 91406942726712) and requeue
# 		Image retrieved (frame ID = 84, timestamp (ns) = 91406983710312) and requeue
# 		Image retrieved (frame ID = 85, timestamp (ns) = 91407024693912) and requeue
# 		Image retrieved (frame ID = 86, timestamp (ns) = 91407065677512) and requeue
# 		Image retrieved (frame ID = 87, timestamp (ns) = 91407106661112) and requeue
# 		Image retrieved (frame ID = 88, timestamp (ns) = 91407147644512) and requeue
# 		Image retrieved (frame ID = 89, timestamp (ns) = 91407188628112) and requeue
# 		Image retrieved (frame ID = 90, timestamp (ns) = 91407229611712) and requeue
# 		Image retrieved (frame ID = 91, timestamp (ns) = 91407270595312) and requeue
# 		Image retrieved (frame ID = 92, timestamp (ns) = 91407311578912) and requeue
# 		Image retrieved (frame ID = 93, timestamp (ns) = 91407352562512) and requeue
# 		Image retrieved (frame ID = 94, timestamp (ns) = 91407393546112) and requeue
# 		Image retrieved (frame ID = 95, timestamp (ns) = 91407434529512) and requeue
# 		Image retrieved (frame ID = 96, timestamp (ns) = 91407475513112) and requeue
# 		Image retrieved (frame ID = 97, timestamp (ns) = 91407516496712) and requeue
# 		Image retrieved (frame ID = 98, timestamp (ns) = 91407557480312) and requeue
# 		Image retrieved (frame ID = 99, timestamp (ns) = 91407598463912) and requeue
# 		Image retrieved (frame ID = 100, timestamp (ns) = 91407639447512) and requeue
# 		Image retrieved (frame ID = 101, timestamp (ns) = 91407680430912) and requeue
# 		Image retrieved (frame ID = 102, timestamp (ns) = 91407721414512) and requeue
# 		Image retrieved (frame ID = 103, timestamp (ns) = 91407762398112) and requeue
# 		Image retrieved (frame ID = 104, timestamp (ns) = 91407803381712) and requeue
# 		Image retrieved (frame ID = 105, timestamp (ns) = 91407844365312) and requeue
# 		Image retrieved (frame ID = 106, timestamp (ns) = 91407885348912) and requeue
# 		Image retrieved (frame ID = 107, timestamp (ns) = 91407926332512) and requeue
# 		Image retrieved (frame ID = 108, timestamp (ns) = 91407967315912) and requeue
# 		Image retrieved (frame ID = 109, timestamp (ns) = 91408008299512) and requeue
# 		Image retrieved (frame ID = 110, timestamp (ns) = 91408049283112) and requeue
# 		Image retrieved (frame ID = 111, timestamp (ns) = 91408090266712) and requeue
# 		Image retrieved (frame ID = 112, timestamp (ns) = 91408131250312) and requeue
# 		Image retrieved (frame ID = 113, timestamp (ns) = 91408172233912) and requeue
# 		Image retrieved (frame ID = 114, timestamp (ns) = 91408213217312) and requeue
# 		Image retrieved (frame ID = 115, timestamp (ns) = 91408254200912) and requeue
# 		Image retrieved (frame ID = 116, timestamp (ns) = 91408295184512) and requeue
# 		Image retrieved (frame ID = 117, timestamp (ns) = 91408336168112) and requeue
# 		Image retrieved (frame ID = 118, timestamp (ns) = 91408377151712) and requeue
# 		Image retrieved (frame ID = 119, timestamp (ns) = 91408418135312) and requeue
# 		Image retrieved (frame ID = 120, timestamp (ns) = 91408459118712) and requeue
# 		Image retrieved (frame ID = 121, timestamp (ns) = 91408500102312) and requeue
# 		Image retrieved (frame ID = 122, timestamp (ns) = 91408541085912) and requeue
# 		Image retrieved (frame ID = 123, timestamp (ns) = 91408582069512) and requeue
# 		Image retrieved (frame ID = 124, timestamp (ns) = 91408623053112) and requeue
# 		Image retrieved (frame ID = 125, timestamp (ns) = 91408664036712) and requeue
# 		Image retrieved (frame ID = 126, timestamp (ns) = 91408705020312) and requeue
# 		Image retrieved (frame ID = 127, timestamp (ns) = 91408746003712) and requeue
# 		Image retrieved (frame ID = 128, timestamp (ns) = 91408786987312) and requeue
# 		Image retrieved (frame ID = 129, timestamp (ns) = 91408827970912) and requeue
# 		Image retrieved (frame ID = 130, timestamp (ns) = 91408868954512) and requeue
# 		Image retrieved (frame ID = 131, timestamp (ns) = 91408909938112) and requeue
# 		Image retrieved (frame ID = 132, timestamp (ns) = 91408950921712) and requeue
# 		Image retrieved (frame ID = 133, timestamp (ns) = 91408991905112) and requeue
# 		Image retrieved (frame ID = 134, timestamp (ns) = 91409032888712) and requeue
# 		Image retrieved (frame ID = 135, timestamp (ns) = 91409073872312) and requeue
# 		Image retrieved (frame ID = 136, timestamp (ns) = 91409114855912) and requeue
# 		Image retrieved (frame ID = 137, timestamp (ns) = 91409155839512) and requeue
# 		Image retrieved (frame ID = 138, timestamp (ns) = 91409196823112) and requeue
# 		Image retrieved (frame ID = 139, timestamp (ns) = 91409237806712) and requeue
# 		Image retrieved (frame ID = 140, timestamp (ns) = 91409278790112) and requeue
# 		Image retrieved (frame ID = 141, timestamp (ns) = 91409319773712) and requeue
# 		Image retrieved (frame ID = 142, timestamp (ns) = 91409360757312) and requeue
# 		Image retrieved (frame ID = 143, timestamp (ns) = 91409401740912) and requeue
# 		Image retrieved (frame ID = 144, timestamp (ns) = 91409442724512) and requeue
# 		Image retrieved (frame ID = 145, timestamp (ns) = 91409483708112) and requeue
# 		Image retrieved (frame ID = 146, timestamp (ns) = 91409524691512) and requeue
# 		Image retrieved (frame ID = 147, timestamp (ns) = 91409565675112) and requeue
# 		Image retrieved (frame ID = 148, timestamp (ns) = 91409606658712) and requeue
# 		Image retrieved (frame ID = 149, timestamp (ns) = 91409647642312) and requeue
# 		Image retrieved (frame ID = 150, timestamp (ns) = 91409688625912) and requeue
# 		Image retrieved (frame ID = 151, timestamp (ns) = 91409729609512) and requeue
# 		Image retrieved (frame ID = 152, timestamp (ns) = 91409770592912) and requeue
# 		Image retrieved (frame ID = 153, timestamp (ns) = 91409811576512) and requeue
# 		Image retrieved (frame ID = 154, timestamp (ns) = 91409852560112) and requeue
# 		Image retrieved (frame ID = 155, timestamp (ns) = 91409893543712) and requeue
# 		Image retrieved (frame ID = 156, timestamp (ns) = 91409934527312) and requeue
# 		Image retrieved (frame ID = 157, timestamp (ns) = 91409975510912) and requeue
# 		Image retrieved (frame ID = 158, timestamp (ns) = 91410016494512) and requeue
# 		Image retrieved (frame ID = 159, timestamp (ns) = 91410057477912) and requeue
# 		Image retrieved (frame ID = 160, timestamp (ns) = 91410098461512) and requeue
# 		Image retrieved (frame ID = 161, timestamp (ns) = 91410139445112) and requeue
# 		Image retrieved (frame ID = 162, timestamp (ns) = 91410180428712) and requeue
# 		Image retrieved (frame ID = 163, timestamp (ns) = 91410221412312) and requeue
# 		Image retrieved (frame ID = 164, timestamp (ns) = 91410262395912) and requeue
# 		Image retrieved (frame ID = 165, timestamp (ns) = 91410303379312) and requeue
# 		Image retrieved (frame ID = 166, timestamp (ns) = 91410344362912) and requeue
# 		Image retrieved (frame ID = 167, timestamp (ns) = 91410385346512) and requeue
# 		Image retrieved (frame ID = 168, timestamp (ns) = 91410426330112) and requeue
# 		Image retrieved (frame ID = 169, timestamp (ns) = 91410467313712) and requeue
# 		Image retrieved (frame ID = 170, timestamp (ns) = 91410508297312) and requeue
# 		Image retrieved (frame ID = 171, timestamp (ns) = 91410549280912) and requeue
# 		Image retrieved (frame ID = 172, timestamp (ns) = 91410590264312) and requeue
# 		Image retrieved (frame ID = 173, timestamp (ns) = 91410631247912) and requeue
# 		Image retrieved (frame ID = 174, timestamp (ns) = 91410672231512) and requeue
# 		Image retrieved (frame ID = 175, timestamp (ns) = 91410713215112) and requeue
# 		Image retrieved (frame ID = 176, timestamp (ns) = 91410754198712) and requeue
# 		Image retrieved (frame ID = 177, timestamp (ns) = 91410795182312) and requeue
# 		Image retrieved (frame ID = 178, timestamp (ns) = 91410836165712) and requeue
# 		Image retrieved (frame ID = 179, timestamp (ns) = 91410877149312) and requeue
# 		Image retrieved (frame ID = 180, timestamp (ns) = 91410918132912) and requeue
# 		Image retrieved (frame ID = 181, timestamp (ns) = 91410959116512) and requeue
# 		Image retrieved (frame ID = 182, timestamp (ns) = 91411000100112) and requeue
# 		Image retrieved (frame ID = 183, timestamp (ns) = 91411041083712) and requeue
# 		Image retrieved (frame ID = 184, timestamp (ns) = 91411082067112) and requeue
# 		Image retrieved (frame ID = 185, timestamp (ns) = 91411123050712) and requeue
# 		Image retrieved (frame ID = 186, timestamp (ns) = 91411164034312) and requeue
# 		Image retrieved (frame ID = 187, timestamp (ns) = 91411205017912) and requeue
# 		Image retrieved (frame ID = 188, timestamp (ns) = 91411246001512) and requeue
# 		Image retrieved (frame ID = 189, timestamp (ns) = 91411286985112) and requeue
# 		Image retrieved (frame ID = 190, timestamp (ns) = 91411327968712) and requeue
# 		Image retrieved (frame ID = 191, timestamp (ns) = 91411368952112) and requeue
# 		Image retrieved (frame ID = 192, timestamp (ns) = 91411409935712) and requeue
# 		Image retrieved (frame ID = 193, timestamp (ns) = 91411450919312) and requeue
# 		Image retrieved (frame ID = 194, timestamp (ns) = 91411491902912) and requeue
# 		Image retrieved (frame ID = 195, timestamp (ns) = 91411532886512) and requeue
# 		Image retrieved (frame ID = 196, timestamp (ns) = 91411573870112) and requeue
# 		Image retrieved (frame ID = 197, timestamp (ns) = 91411614853512) and requeue
# 		Image retrieved (frame ID = 198, timestamp (ns) = 91411655837112) and requeue
# 		Image retrieved (frame ID = 199, timestamp (ns) = 91411696820712) and requeue
# 		Image retrieved (frame ID = 200, timestamp (ns) = 91411737804312) and requeue
# 		Image retrieved (frame ID = 201, timestamp (ns) = 91411778787912) and requeue
# 		Image retrieved (frame ID = 202, timestamp (ns) = 91411819771512) and requeue
# 		Image retrieved (frame ID = 203, timestamp (ns) = 91411860755112) and requeue
# 		Image retrieved (frame ID = 204, timestamp (ns) = 91411901738512) and requeue
# 		Image retrieved (frame ID = 205, timestamp (ns) = 91411942722112) and requeue
# 		Image retrieved (frame ID = 206, timestamp (ns) = 91411983705712) and requeue
# 		Image retrieved (frame ID = 207, timestamp (ns) = 91412024689312) and requeue
# 		Image retrieved (frame ID = 208, timestamp (ns) = 91412065672912) and requeue
# 		Image retrieved (frame ID = 209, timestamp (ns) = 91412106656512) and requeue
# 		Image retrieved (frame ID = 210, timestamp (ns) = 91412147639912) and requeue
# 		Image retrieved (frame ID = 211, timestamp (ns) = 91412188623512) and requeue
# 		Image retrieved (frame ID = 212, timestamp (ns) = 91412229607112) and requeue
# 		Image retrieved (frame ID = 213, timestamp (ns) = 91412270590712) and requeue
# 		Image retrieved (frame ID = 214, timestamp (ns) = 91412311574312) and requeue
# 		Image retrieved (frame ID = 215, timestamp (ns) = 91412352557912) and requeue
# 		Image retrieved (frame ID = 216, timestamp (ns) = 91412393541312) and requeue
# 		Image retrieved (frame ID = 217, timestamp (ns) = 91412434524912) and requeue
# 		Image retrieved (frame ID = 218, timestamp (ns) = 91412475508512) and requeue
# 		Image retrieved (frame ID = 219, timestamp (ns) = 91412516492112) and requeue
# 		Image retrieved (frame ID = 220, timestamp (ns) = 91412557475712) and requeue
# 		Image retrieved (frame ID = 221, timestamp (ns) = 91412598459312) and requeue
# 		Image retrieved (frame ID = 222, timestamp (ns) = 91412639442912) and requeue
# 		Image retrieved (frame ID = 223, timestamp (ns) = 91412680426312) and requeue
# 		Image retrieved (frame ID = 224, timestamp (ns) = 91412721409912) and requeue
# 		Image retrieved (frame ID = 225, timestamp (ns) = 91412762393512) and requeue
# 		Image retrieved (frame ID = 226, timestamp (ns) = 91412803377112) and requeue
# 		Image retrieved (frame ID = 227, timestamp (ns) = 91412844360712) and requeue
# 		Image retrieved (frame ID = 228, timestamp (ns) = 91412885344312) and requeue
# 		Image retrieved (frame ID = 229, timestamp (ns) = 91412926327712) and requeue
# 		Image retrieved (frame ID = 230, timestamp (ns) = 91412967311312) and requeue
# 		Image retrieved (frame ID = 231, timestamp (ns) = 91413008294912) and requeue
# 		Image retrieved (frame ID = 232, timestamp (ns) = 91413049278512) and requeue
# 		Image retrieved (frame ID = 233, timestamp (ns) = 91413090262112) and requeue
# 		Image retrieved (frame ID = 234, timestamp (ns) = 91413131245712) and requeue
# 		Image retrieved (frame ID = 235, timestamp (ns) = 91413172229312) and requeue
# 		Image retrieved (frame ID = 236, timestamp (ns) = 91413213212712) and requeue
# 		Image retrieved (frame ID = 237, timestamp (ns) = 91413254196312) and requeue
# 		Image retrieved (frame ID = 238, timestamp (ns) = 91413295179912) and requeue
# 		Image retrieved (frame ID = 239, timestamp (ns) = 91413336163512) and requeue
# 		Image retrieved (frame ID = 240, timestamp (ns) = 91413377147112) and requeue
# 		Image retrieved (frame ID = 241, timestamp (ns) = 91413418130712) and requeue
# 		Image retrieved (frame ID = 242, timestamp (ns) = 91413459114112) and requeue
# 		Image retrieved (frame ID = 243, timestamp (ns) = 91413500097712) and requeue
# 		Image retrieved (frame ID = 244, timestamp (ns) = 91413541081312) and requeue
# 		Image retrieved (frame ID = 245, timestamp (ns) = 91413582064912) and requeue
# 		Image retrieved (frame ID = 246, timestamp (ns) = 91413623048512) and requeue
# 		Image retrieved (frame ID = 247, timestamp (ns) = 91413664032112) and requeue
# 		Image retrieved (frame ID = 248, timestamp (ns) = 91413705015512) and requeue
# 		Image retrieved (frame ID = 249, timestamp (ns) = 91413745999112) and requeue
# 		Image retrieved (frame ID = 250, timestamp (ns) = 91413786982712) and requeue
# 		Image retrieved (frame ID = 251, timestamp (ns) = 91413827966312) and requeue
# 		Image retrieved (frame ID = 252, timestamp (ns) = 91413868949912) and requeue
# 		Image retrieved (frame ID = 253, timestamp (ns) = 91413909933512) and requeue
# 		Image retrieved (frame ID = 254, timestamp (ns) = 91413950917112) and requeue
# 		Image retrieved (frame ID = 255, timestamp (ns) = 91413991900512) and requeue
# 		Image retrieved (frame ID = 256, timestamp (ns) = 91414032884112) and requeue
# 		Image retrieved (frame ID = 257, timestamp (ns) = 91414073867712) and requeue
# 		Image retrieved (frame ID = 258, timestamp (ns) = 91414114851312) and requeue
# 		Image retrieved (frame ID = 259, timestamp (ns) = 91414155834912) and requeue
# 		Image retrieved (frame ID = 260, timestamp (ns) = 91414196818512) and requeue
# 		Image retrieved (frame ID = 261, timestamp (ns) = 91414237801912) and requeue
# 		Image retrieved (frame ID = 262, timestamp (ns) = 91414278785512) and requeue
# 		Image retrieved (frame ID = 263, timestamp (ns) = 91414319769112) and requeue
# 		Image retrieved (frame ID = 264, timestamp (ns) = 91414360752712) and requeue
# 		Image retrieved (frame ID = 265, timestamp (ns) = 91414401736312) and requeue
# 		Image retrieved (frame ID = 266, timestamp (ns) = 91414442719912) and requeue
# 		Image retrieved (frame ID = 267, timestamp (ns) = 91414483703512) and requeue
# 		Image retrieved (frame ID = 268, timestamp (ns) = 91414524686912) and requeue
# 		Image retrieved (frame ID = 269, timestamp (ns) = 91414565670512) and requeue
# 		Image retrieved (frame ID = 270, timestamp (ns) = 91414606654112) and requeue
# 		Image retrieved (frame ID = 271, timestamp (ns) = 91414647637712) and requeue
# 		Image retrieved (frame ID = 272, timestamp (ns) = 91414688621312) and requeue
# 		Image retrieved (frame ID = 273, timestamp (ns) = 91414729604912) and requeue
# 		Image retrieved (frame ID = 274, timestamp (ns) = 91414770588312) and requeue
# 		Image retrieved (frame ID = 275, timestamp (ns) = 91414811571912) and requeue
# 		Image retrieved (frame ID = 276, timestamp (ns) = 91414852555512) and requeue
# 		Image retrieved (frame ID = 277, timestamp (ns) = 91414893539112) and requeue
# 		Image retrieved (frame ID = 278, timestamp (ns) = 91414934522712) and requeue
# 		Image retrieved (frame ID = 279, timestamp (ns) = 91414975506312) and requeue
# 		Image retrieved (frame ID = 280, timestamp (ns) = 91415016489712) and requeue
# 		Image retrieved (frame ID = 281, timestamp (ns) = 91415057473312) and requeue
# 		Image retrieved (frame ID = 282, timestamp (ns) = 91415098456912) and requeue
# 		Image retrieved (frame ID = 283, timestamp (ns) = 91415139440512) and requeue
# 		Image retrieved (frame ID = 284, timestamp (ns) = 91415180424112) and requeue
# 		Image retrieved (frame ID = 285, timestamp (ns) = 91415221407712) and requeue
# 		Image retrieved (frame ID = 286, timestamp (ns) = 91415262391312) and requeue
# 		Image retrieved (frame ID = 287, timestamp (ns) = 91415303374712) and requeue
# 		Image retrieved (frame ID = 288, timestamp (ns) = 91415344358312) and requeue
# 		Image retrieved (frame ID = 289, timestamp (ns) = 91415385341912) and requeue
# 		Image retrieved (frame ID = 290, timestamp (ns) = 91415426325512) and requeue
# 		Image retrieved (frame ID = 291, timestamp (ns) = 91415467309112) and requeue
# 		Image retrieved (frame ID = 292, timestamp (ns) = 91415508292712) and requeue
# 		Image retrieved (frame ID = 293, timestamp (ns) = 91415549276112) and requeue
# 		Image retrieved (frame ID = 294, timestamp (ns) = 91415590259712) and requeue
# 		Image retrieved (frame ID = 295, timestamp (ns) = 91415631243312) and requeue
# 		Image retrieved (frame ID = 296, timestamp (ns) = 91415672226912) and requeue
# 		Image retrieved (frame ID = 297, timestamp (ns) = 91415713210512) and requeue
# 		Image retrieved (frame ID = 298, timestamp (ns) = 91415754194112) and requeue
# 		Image retrieved (frame ID = 299, timestamp (ns) = 91415795177712) and requeue
# 		Image retrieved (frame ID = 300, timestamp (ns) = 91415836161112) and requeue
# 		Image retrieved (frame ID = 301, timestamp (ns) = 91415877144712) and requeue
# 		Image retrieved (frame ID = 302, timestamp (ns) = 91415918128312) and requeue
# 		Image retrieved (frame ID = 303, timestamp (ns) = 91415959111912) and requeue
# 		Image retrieved (frame ID = 304, timestamp (ns) = 91416000095512) and requeue
# 		Image retrieved (frame ID = 305, timestamp (ns) = 91416041079112) and requeue
# 		Image retrieved (frame ID = 306, timestamp (ns) = 91416082062512) and requeue
# 		Image retrieved (frame ID = 307, timestamp (ns) = 91416123046112) and requeue
# 		Image retrieved (frame ID = 308, timestamp (ns) = 91416164029712) and requeue
# 		Image retrieved (frame ID = 309, timestamp (ns) = 91416205013312) and requeue
# 		Image retrieved (frame ID = 310, timestamp (ns) = 91416245996912) and requeue
# 		Image retrieved (frame ID = 311, timestamp (ns) = 91416286980512) and requeue
# 		Image retrieved (frame ID = 312, timestamp (ns) = 91416327963912) and requeue
# 		Image retrieved (frame ID = 313, timestamp (ns) = 91416368947512) and requeue
# 		Image retrieved (frame ID = 314, timestamp (ns) = 91416409931112) and requeue
# 		Image retrieved (frame ID = 315, timestamp (ns) = 91416450914712) and requeue
# 		Image retrieved (frame ID = 316, timestamp (ns) = 91416491898312) and requeue
# 		Image retrieved (frame ID = 317, timestamp (ns) = 91416532881912) and requeue
# 		Image retrieved (frame ID = 318, timestamp (ns) = 91416573865512) and requeue
# 		Image retrieved (frame ID = 319, timestamp (ns) = 91416614848912) and requeue
# 		Image retrieved (frame ID = 320, timestamp (ns) = 91416655832512) and requeue
# 		Image retrieved (frame ID = 321, timestamp (ns) = 91416696816112) and requeue
# 		Image retrieved (frame ID = 322, timestamp (ns) = 91416737799712) and requeue
# 		Image retrieved (frame ID = 323, timestamp (ns) = 91416778783312) and requeue
# 		Image retrieved (frame ID = 324, timestamp (ns) = 91416819766912) and requeue
# 		Image retrieved (frame ID = 325, timestamp (ns) = 91416860750312) and requeue
# 		Image retrieved (frame ID = 326, timestamp (ns) = 91416901733912) and requeue
# 		Image retrieved (frame ID = 327, timestamp (ns) = 91416942717512) and requeue
# 		Image retrieved (frame ID = 328, timestamp (ns) = 91416983701112) and requeue
# 		Image retrieved (frame ID = 329, timestamp (ns) = 91417024684712) and requeue
# 		Image retrieved (frame ID = 330, timestamp (ns) = 91417065668312) and requeue
# 		Image retrieved (frame ID = 331, timestamp (ns) = 91417106651912) and requeue
# 		Image retrieved (frame ID = 332, timestamp (ns) = 91417147635312) and requeue
# 		Image retrieved (frame ID = 333, timestamp (ns) = 91417188618912) and requeue
# 		Image retrieved (frame ID = 334, timestamp (ns) = 91417229602512) and requeue
# 		Image retrieved (frame ID = 335, timestamp (ns) = 91417270586112) and requeue
# 		Image retrieved (frame ID = 336, timestamp (ns) = 91417311569712) and requeue
# 		Image retrieved (frame ID = 337, timestamp (ns) = 91417352553312) and requeue
# 		Image retrieved (frame ID = 338, timestamp (ns) = 91417393536712) and requeue
# 		Image retrieved (frame ID = 339, timestamp (ns) = 91417434520312) and requeue
# 		Image retrieved (frame ID = 340, timestamp (ns) = 91417475503912) and requeue
# 		Image retrieved (frame ID = 341, timestamp (ns) = 91417516487512) and requeue
# 		Image retrieved (frame ID = 342, timestamp (ns) = 91417557471112) and requeue
# 		Image retrieved (frame ID = 343, timestamp (ns) = 91417598454712) and requeue
# 		Image retrieved (frame ID = 344, timestamp (ns) = 91417639438112) and requeue
# 		Image retrieved (frame ID = 345, timestamp (ns) = 91417680421712) and requeue
# 		Image retrieved (frame ID = 346, timestamp (ns) = 91417721405312) and requeue
# 		Image retrieved (frame ID = 347, timestamp (ns) = 91417762388912) and requeue
# 		Image retrieved (frame ID = 348, timestamp (ns) = 91417803372512) and requeue
# 		Image retrieved (frame ID = 349, timestamp (ns) = 91417844356112) and requeue
# 		Image retrieved (frame ID = 350, timestamp (ns) = 91417885339712) and requeue
# 		Image retrieved (frame ID = 351, timestamp (ns) = 91417926323112) and requeue
# 		Image retrieved (frame ID = 352, timestamp (ns) = 91417967306712) and requeue
# 		Image retrieved (frame ID = 353, timestamp (ns) = 91418008290312) and requeue
# 		Image retrieved (frame ID = 354, timestamp (ns) = 91418049273912) and requeue
# 		Image retrieved (frame ID = 355, timestamp (ns) = 91418090257512) and requeue
# 		Image retrieved (frame ID = 356, timestamp (ns) = 91418131241112) and requeue
# 		Image retrieved (frame ID = 357, timestamp (ns) = 91418172224512) and requeue
# 		Image retrieved (frame ID = 358, timestamp (ns) = 91418213208112) and requeue
# 		Image retrieved (frame ID = 359, timestamp (ns) = 91418254191712) and requeue
# 		Image retrieved (frame ID = 360, timestamp (ns) = 91418295175312) and requeue
# 		Image retrieved (frame ID = 361, timestamp (ns) = 91418336158912) and requeue
# 		Image retrieved (frame ID = 362, timestamp (ns) = 91418377142512) and requeue
# 		Image retrieved (frame ID = 363, timestamp (ns) = 91418418126112) and requeue
# 		Image retrieved (frame ID = 364, timestamp (ns) = 91418459109512) and requeue
# 		Image retrieved (frame ID = 365, timestamp (ns) = 91418500093112) and requeue
# 		Image retrieved (frame ID = 366, timestamp (ns) = 91418541076712) and requeue
# 		Image retrieved (frame ID = 367, timestamp (ns) = 91418582060312) and requeue
# 		Image retrieved (frame ID = 368, timestamp (ns) = 91418623043912) and requeue
# 		Image retrieved (frame ID = 369, timestamp (ns) = 91418664027512) and requeue
# 		Image retrieved (frame ID = 370, timestamp (ns) = 91418705010912) and requeue
# 		Image retrieved (frame ID = 371, timestamp (ns) = 91418745994512) and requeue
# 		Image retrieved (frame ID = 372, timestamp (ns) = 91418786978112) and requeue
# 		Image retrieved (frame ID = 373, timestamp (ns) = 91418827961712) and requeue
# 		Image retrieved (frame ID = 374, timestamp (ns) = 91418868945312) and requeue
# 		Image retrieved (frame ID = 375, timestamp (ns) = 91418909928912) and requeue
# 		Image retrieved (frame ID = 376, timestamp (ns) = 91418950912312) and requeue
# 		Image retrieved (frame ID = 377, timestamp (ns) = 91418991895912) and requeue
# 		Image retrieved (frame ID = 378, timestamp (ns) = 91419032879512) and requeue
# 		Image retrieved (frame ID = 379, timestamp (ns) = 91419073863112) and requeue
# 		Image retrieved (frame ID = 380, timestamp (ns) = 91419114846712) and requeue
# 		Image retrieved (frame ID = 381, timestamp (ns) = 91419155830312) and requeue
# 		Image retrieved (frame ID = 382, timestamp (ns) = 91419196813912) and requeue
# 		Image retrieved (frame ID = 383, timestamp (ns) = 91419237797312) and requeue
# 		Image retrieved (frame ID = 384, timestamp (ns) = 91419278780912) and requeue
# 		Image retrieved (frame ID = 385, timestamp (ns) = 91419319764512) and requeue
# 		Image retrieved (frame ID = 386, timestamp (ns) = 91419360748112) and requeue
# 		Image retrieved (frame ID = 387, timestamp (ns) = 91419401731712) and requeue
# 		Image retrieved (frame ID = 388, timestamp (ns) = 91419442715312) and requeue
# 		Image retrieved (frame ID = 389, timestamp (ns) = 91419483698712) and requeue
# 		Image retrieved (frame ID = 390, timestamp (ns) = 91419524682312) and requeue
# 		Image retrieved (frame ID = 391, timestamp (ns) = 91419565665912) and requeue
# 		Image retrieved (frame ID = 392, timestamp (ns) = 91419606649512) and requeue
# 		Image retrieved (frame ID = 393, timestamp (ns) = 91419647633112) and requeue
# 		Image retrieved (frame ID = 394, timestamp (ns) = 91419688616712) and requeue
# 		Image retrieved (frame ID = 395, timestamp (ns) = 91419729600312) and requeue
# 		Image retrieved (frame ID = 396, timestamp (ns) = 91419770583712) and requeue
# 		Image retrieved (frame ID = 397, timestamp (ns) = 91419811567312) and requeue
# 		Image retrieved (frame ID = 398, timestamp (ns) = 91419852550912) and requeue
# 		Image retrieved (frame ID = 399, timestamp (ns) = 91419893534512) and requeue
# 		Image retrieved (frame ID = 400, timestamp (ns) = 91419934518112) and requeue
# 		Image retrieved (frame ID = 401, timestamp (ns) = 91419975501712) and requeue
# 		Image retrieved (frame ID = 402, timestamp (ns) = 91420016485112) and requeue
# 		Image retrieved (frame ID = 403, timestamp (ns) = 91420057468712) and requeue
# 		Image retrieved (frame ID = 404, timestamp (ns) = 91420098452312) and requeue
# 		Image retrieved (frame ID = 405, timestamp (ns) = 91420139435912) and requeue
# 		Image retrieved (frame ID = 406, timestamp (ns) = 91420180419512) and requeue
# 		Image retrieved (frame ID = 407, timestamp (ns) = 91420221403112) and requeue
# 		Image retrieved (frame ID = 408, timestamp (ns) = 91420262386512) and requeue
# 		Image retrieved (frame ID = 409, timestamp (ns) = 91420303370112) and requeue
# 		Image retrieved (frame ID = 410, timestamp (ns) = 91420344353712) and requeue
# 		Image retrieved (frame ID = 411, timestamp (ns) = 91420385337312) and requeue
# 		Image retrieved (frame ID = 412, timestamp (ns) = 91420426320912) and requeue
# 		Image retrieved (frame ID = 413, timestamp (ns) = 91420467304512) and requeue
# 		Image retrieved (frame ID = 414, timestamp (ns) = 91420508288112) and requeue
# 		Image retrieved (frame ID = 415, timestamp (ns) = 91420549271512) and requeue
# 		Image retrieved (frame ID = 416, timestamp (ns) = 91420590255112) and requeue
# 		Image retrieved (frame ID = 417, timestamp (ns) = 91420631238712) and requeue
# 		Image retrieved (frame ID = 418, timestamp (ns) = 91420672222312) and requeue
# 		Image retrieved (frame ID = 419, timestamp (ns) = 91420713205912) and requeue
# 		Image retrieved (frame ID = 420, timestamp (ns) = 91420754189512) and requeue
# 		Image retrieved (frame ID = 421, timestamp (ns) = 91420795172912) and requeue
# 		Image retrieved (frame ID = 422, timestamp (ns) = 91420836156512) and requeue
# 		Image retrieved (frame ID = 423, timestamp (ns) = 91420877140112) and requeue
# 		Image retrieved (frame ID = 424, timestamp (ns) = 91420918123712) and requeue
# 		Image retrieved (frame ID = 425, timestamp (ns) = 91420959107312) and requeue
# 		Image retrieved (frame ID = 426, timestamp (ns) = 91421000090912) and requeue
# 		Image retrieved (frame ID = 427, timestamp (ns) = 91421041074512) and requeue
# 		Image retrieved (frame ID = 428, timestamp (ns) = 91421082057912) and requeue
# 		Image retrieved (frame ID = 429, timestamp (ns) = 91421123041512) and requeue
# 		Image retrieved (frame ID = 430, timestamp (ns) = 91421164025112) and requeue
# 		Image retrieved (frame ID = 431, timestamp (ns) = 91421205008712) and requeue
# 		Image retrieved (frame ID = 432, timestamp (ns) = 91421245992312) and requeue
# 		Image retrieved (frame ID = 433, timestamp (ns) = 91421286975912) and requeue
# 		Image retrieved (frame ID = 434, timestamp (ns) = 91421327959312) and requeue
# 		Image retrieved (frame ID = 435, timestamp (ns) = 91421368942912) and requeue
# 		Image retrieved (frame ID = 436, timestamp (ns) = 91421409926512) and requeue
# 		Image retrieved (frame ID = 437, timestamp (ns) = 91421450910112) and requeue
# 		Image retrieved (frame ID = 438, timestamp (ns) = 91421491893712) and requeue
# 		Image retrieved (frame ID = 439, timestamp (ns) = 91421532877312) and requeue
# 		Image retrieved (frame ID = 440, timestamp (ns) = 91421573860712) and requeue
# 		Image retrieved (frame ID = 441, timestamp (ns) = 91421614844312) and requeue
# 		Image retrieved (frame ID = 442, timestamp (ns) = 91421655827912) and requeue
# 		Image retrieved (frame ID = 443, timestamp (ns) = 91421696811512) and requeue
# 		Image retrieved (frame ID = 444, timestamp (ns) = 91421737795112) and requeue
# 		Image retrieved (frame ID = 445, timestamp (ns) = 91421778778712) and requeue
# 		Image retrieved (frame ID = 446, timestamp (ns) = 91421819762312) and requeue
# 		Image retrieved (frame ID = 447, timestamp (ns) = 91421860745712) and requeue
# 		Image retrieved (frame ID = 448, timestamp (ns) = 91421901729312) and requeue
# 		Image retrieved (frame ID = 449, timestamp (ns) = 91421942712912) and requeue
# 		Image retrieved (frame ID = 450, timestamp (ns) = 91421983696512) and requeue
# 		Image retrieved (frame ID = 451, timestamp (ns) = 91422024680112) and requeue
# 		Image retrieved (frame ID = 452, timestamp (ns) = 91422065663712) and requeue
# 		Image retrieved (frame ID = 453, timestamp (ns) = 91422106647112) and requeue
# 		Image retrieved (frame ID = 454, timestamp (ns) = 91422147630712) and requeue
# 		Image retrieved (frame ID = 455, timestamp (ns) = 91422188614312) and requeue
# 		Image retrieved (frame ID = 456, timestamp (ns) = 91422229597912) and requeue
# 		Image retrieved (frame ID = 457, timestamp (ns) = 91422270581512) and requeue
# 		Image retrieved (frame ID = 458, timestamp (ns) = 91422311565112) and requeue
# 		Image retrieved (frame ID = 459, timestamp (ns) = 91422352548712) and requeue
# 		Image retrieved (frame ID = 460, timestamp (ns) = 91422393532112) and requeue
# 		Image retrieved (frame ID = 461, timestamp (ns) = 91422434515712) and requeue
# 		Image retrieved (frame ID = 462, timestamp (ns) = 91422475499312) and requeue
# 		Image retrieved (frame ID = 463, timestamp (ns) = 91422516482912) and requeue
# 		Image retrieved (frame ID = 464, timestamp (ns) = 91422557466512) and requeue
# 		Image retrieved (frame ID = 465, timestamp (ns) = 91422598450112) and requeue
# 		Image retrieved (frame ID = 466, timestamp (ns) = 91422639433512) and requeue
# 		Image retrieved (frame ID = 467, timestamp (ns) = 91422680417112) and requeue
# 		Image retrieved (frame ID = 468, timestamp (ns) = 91422721400712) and requeue
# 		Image retrieved (frame ID = 469, timestamp (ns) = 91422762384312) and requeue
# 		Image retrieved (frame ID = 470, timestamp (ns) = 91422803367912) and requeue
# 		Image retrieved (frame ID = 471, timestamp (ns) = 91422844351512) and requeue
# 		Image retrieved (frame ID = 472, timestamp (ns) = 91422885334912) and requeue
# 		Image retrieved (frame ID = 473, timestamp (ns) = 91422926318512) and requeue
# 		Image retrieved (frame ID = 474, timestamp (ns) = 91422967302112) and requeue
# 		Image retrieved (frame ID = 475, timestamp (ns) = 91423008285712) and requeue
# 		Image retrieved (frame ID = 476, timestamp (ns) = 91423049269312) and requeue
# 		Image retrieved (frame ID = 477, timestamp (ns) = 91423090252912) and requeue
# 		Image retrieved (frame ID = 478, timestamp (ns) = 91423131236512) and requeue
# 		Image retrieved (frame ID = 479, timestamp (ns) = 91423172219912) and requeue
# 		Image retrieved (frame ID = 480, timestamp (ns) = 91423213203512) and requeue
# 		Image retrieved (frame ID = 481, timestamp (ns) = 91423254187112) and requeue
# 		Image retrieved (frame ID = 482, timestamp (ns) = 91423295170712) and requeue
# 		Image retrieved (frame ID = 483, timestamp (ns) = 91423336154312) and requeue
# 		Image retrieved (frame ID = 484, timestamp (ns) = 91423377137912) and requeue
