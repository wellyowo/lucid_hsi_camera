# %%
"""
 ***************************************************************************************
 ***                                                                                 ***
 ***  Copyright (c) 2022, Lucid Vision Labs, Inc.                                    ***
 ***                                                                                 ***
 ***  THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR     ***
 ***  IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES OF MERCHANTABILITY,       ***
 ***  FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE    ***
 ***  AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER         ***
 ***  LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM,  ***
 ***  OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE  ***
 ***  SOFTWARE.                                                                      ***
 ***                                                                                 ***
 ***************************************************************************************
 """

# %%
import time
from arena_api.system import system

# %%
"""
Explore: Nodes
    This example explores traversing the nodes as a tree and fundamental node
    information including display name, access mode visibility, interface type,
    and value.
"""

# %%
"""
Choose node properties to explore
"""
explore_access = True
explore_visibility = True
explore_type = True
explore_value = True

# %%
"""
Waits for the user to connect a device before raising
an exception if it fails
"""
tries = 0
tries_max = 6
sleep_time_secs = 10
devices = None
while tries < tries_max:  # Wait for device for 60 seconds
    devices = system.create_device()
    if not devices:
        print(
            f'Try {tries+1} of {tries_max}: waiting for {sleep_time_secs} '
            f'secs for a device to be connected!')
        for sec_count in range(sleep_time_secs):
            time.sleep(1)
            print(f'{sec_count + 1 } seconds passed ',
                    '.' * sec_count, end='\r')
        tries += 1
    else:
        print(f'Created {len(devices)} device(s)')
        break
else:
    raise Exception(f'No device found! Please connect a device and run '
                    f'the example again.')

device = devices[0]
nodemap = device.nodemap
print(f'Device used in the example:\n\t{device}')
# Out:
# Created 1 device(s)
# Device used in the example:
# 	('1c:0f:af:12:53:65', 'PHX050S-C', 'new', '184.123.0.41')

# %%
def explore_node(node, nodemap, depth):
    """
    explores node
    (1) retrieves display name
    (2) retrieves accessibility
    (3) retrieves visibility
    (4) retrieves interface type
    (5) retrieves value
    """
    # Get display name
    display_name = node.display_name

    # Retrieve accessibility
    access_mode = node.access_mode
    access_mode_str = str(access_mode)

    # Retrieve visibility
    visibility = node.visibility
    visibility_str = str(visibility)

    # Retrieve interface type
    interface_type = node.interface_type
    interface_type_str = str(interface_type)

    # Retrieve value if node is not a category or register node and is readable
    value = "-"
    if (node.is_readable and
       (node.interface_type.value != 7 and node.interface_type.value != 8)):
        value = str(node.value)

    # Check and print the desired information
    access_mode_explored = None
    visibility_explored = None
    interface_type_explored = None

    if (explore_access):
        access_mode_explored = access_mode_str

    if (explore_visibility):
        visibility_explored = visibility_str

    if (explore_type):
        interface_type_explored = interface_type_str

    if (explore_value):
        value_explored = value

    print(" " * depth, '{:<40}{:<20}{:<25}{:<30}{:}'.format(display_name,
          access_mode_explored, visibility_explored, interface_type_explored,
          value_explored))

    # Explore category node children
    if (node.interface_type.value == 8):
        children = node.features
        for val in children:
            explore_node(nodemap.get_node(val), nodemap, depth+1)

# %%
# Initialize the Root node, call the explore nodes function
node = nodemap.get_node('Root')
print("Example Started")

explore_node(node, nodemap, 0)

# Cleanup
system.destroy_device()
print("\nExample Finished")
# Out:
# Example Started
#  Root                                    AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#   Device Control                          AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Device Type                             AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     Transmitter
#    Scan Type                               AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     Areascan
#    Vendor Name                             AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          Lucid Vision Labs
#    Model Name                              AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          PHX050S-C
#    Family Name                             AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          Phoenix
#    Device Manufacturer Info                AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          Lucid Vision Labs (www.lucidvisionlabs.com)
#    Device Version                          AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          FHYMY
#    Device Firmware Version                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          1.59.0.0
#    Device Serial Number                    AccessMode.RO       Visibility.BEGINNER      InterfaceType.STRING          420
#    Device User ID                          AccessMode.RW       Visibility.BEGINNER      InterfaceType.STRING          new
#    Device SFNC Version Major               AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         2
#    Device SFNC Version Minor               AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         3
#    Device SFNC Version Sub Minor           AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Device Manifest Entry Selector          AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         1
#    Device Manifest XML Major Version       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         1
#    Device Manifest XML Minor Version       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    Device Manifest XML Sub Minor Version   AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    Device Manifest Schema Major Version    AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         1
#    Device Manifest Schema Minor Version    AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         1
#    Device Manifest Primary URL             AccessMode.RO       Visibility.GURU          InterfaceType.STRING          Local:Lucid Vision Labs_PHX050S-C_rev1_0_3d365d95d7e1242aa625f5569d0743e8.zip;800cac3c;d5b2
#    Device Manifest Secondary URL           AccessMode.RO       Visibility.GURU          InterfaceType.STRING          http://www.thinklucid.com/gev/Lucid Vision Labs_PHX050S-C_rev1_0_3d365d95d7e1242aa625f5569d0743e8.zip
#    Device TL Type                          AccessMode.RO       Visibility.BEGINNER      InterfaceType.ENUMERATION     GigEVision
#    Device TL Version Major                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         2
#    Device TL Version Minor                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Device TL Version Sub Minor             AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         3
#    Device Max Throughput                   AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         178684416
#    Device Link Selector                    AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Device Link Speed                       AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         125000000
#    Device Link Throughput Limit Mode       AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Device Link Throughput Limit            AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         125000000
#    Device Link Throughput Reserve          AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         10
#    Device Link Heartbeat Mode              AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     On
#    Device Link Heartbeat Timeout           AccessMode.RW       Visibility.GURU          InterfaceType.FLOAT           6000000.0
#    Device Link Command Timeout             AccessMode.RO       Visibility.GURU          InterfaceType.FLOAT           200000.0
#    Device Stream Channel Count             AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Device Stream Channel Selector          AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Device Stream Channel Type              AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     Transmitter
#    Device Stream Channel Endianness        AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     Little
#    Device Stream Channel Packet Size       AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         9000
#    Device Event Channel Count              AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Device Character Set                    AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     UTF8
#    Device Reset                            AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Factory Reset                    AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Firmware Update                         AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Feature Persistence Start        AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Feature Persistence End          AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Registers Streaming Start        AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Registers Streaming End          AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Device Indicator Mode                   AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Active
#    Device Temperature Selector             AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Sensor
#    Device Temperature                      AccessMode.RO       Visibility.EXPERT        InterfaceType.FLOAT           54.0
#    Device Pressure                         AccessMode.NI       Visibility.EXPERT        InterfaceType.FLOAT           -
#    Device Power                            AccessMode.RO       Visibility.EXPERT        InterfaceType.FLOAT           2.3025
#    Device Clock Selector                   AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Sensor
#    Device Clock Frequency                  AccessMode.RO       Visibility.EXPERT        InterfaceType.FLOAT           37209000.0
#    Timestamp                               AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         14365373172552
#    Timestamp Reset                         AccessMode.WO       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Timestamp Latch                         AccessMode.WO       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Timestamp Latch Value                   AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Device Up Time                          AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         14360
#    Link Up Time                            AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         14356
#    Localization Language                   AccessMode.RW       Visibility.INVISIBLE     InterfaceType.ENUMERATION     English
#    Localization Address                    AccessMode.RO       Visibility.INVISIBLE     InterfaceType.INTEGER         2148435888
#    Localization Size                       AccessMode.RO       Visibility.INVISIBLE     InterfaceType.INTEGER         23643
#   Acquisition Control                     AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Acquisition Mode                        AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Continuous
#    Acquisition Start                       AccessMode.WO       Visibility.BEGINNER      InterfaceType.COMMAND         -
#    Acquisition Stop                        AccessMode.WO       Visibility.BEGINNER      InterfaceType.COMMAND         -
#    Acquisition Frame Count                 AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         1
#    Acquisition Burst Frame Count           AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         1
#    Acquisition Frame Rate                  AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           40.27386226339106
#    Transmission Frame Rate                 AccessMode.NI       Visibility.BEGINNER      InterfaceType.FLOAT           -
#    Acquisition Frame Rate Enable           AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Acquisition Line Rate                   AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           74415.8356898348
#    Trigger Selector                        AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     FrameStart
#    Trigger Mode                            AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Off
#    Trigger Software                        AccessMode.WO       Visibility.BEGINNER      InterfaceType.COMMAND         -
#    Trigger Source                          AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Line0
#    Trigger Activation                      AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     RisingEdge
#    Trigger Overlap                         AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Trigger Latency                         AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Trigger Delay                           AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           0.0
#    Trigger Armed                           AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Exposure Time                           AccessMode.RW       Visibility.BEGINNER      InterfaceType.FLOAT           24712.776
#    Exposure Time Raw                       AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         3089097
#    Short Exposure Enable                   AccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         False
#    Exposure Auto                           AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Off
#    Exposure Auto Lower Limit               AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           27.168
#    Exposure Auto Upper Limit               AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           1774.112
#    Target Brightness                       AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         128
#    Exposure Auto Algorithm                 AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Mean
#    Exposure Auto Damping                   AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           89.84375
#    Exposure Auto Damping Raw               AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         230
#    Calculated Median                       AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         4
#    Calculated Average                      AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         23
#    Auto Exposure AOI                       AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#     AOI Enable                              AccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         False
#     AOI Width                               AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#     AOI Height                              AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#     AOI OffsetX                             AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#     AOI OffsetY                             AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#   Event Control                           AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Event Selector                          AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     ExposureStart
#    Event Notification                      AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Event Destination Address               AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Event Exposure Start Data               AccessMode.NI       Visibility.EXPERT        InterfaceType.CATEGORY        -
#     Event Exposure Start                    AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#     Event Exposure Start Timestamp          AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#     Event Exposure Start Frame ID           AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Event Exposure End Data                 AccessMode.NI       Visibility.EXPERT        InterfaceType.CATEGORY        -
#     Event Exposure End                      AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#     Event Exposure End Timestamp            AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#     Event Exposure End Frame ID             AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Event Test Data                         AccessMode.NI       Visibility.EXPERT        InterfaceType.CATEGORY        -
#     Event Test                              AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#     Event Test Timestamp                    AccessMode.NI       Visibility.EXPERT        InterfaceType.INTEGER         -
#   User Set Control                        AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    User Set Selector                       AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Default
#    User Set Load                           AccessMode.WO       Visibility.BEGINNER      InterfaceType.COMMAND         -
#    User Set Save                           AccessMode.NA       Visibility.BEGINNER      InterfaceType.COMMAND         -
#    User Set Default                        AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Default
#    User Set Feature Selector               AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     ADCBitDepth
#    User Set Feature Enable                 AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#   Test Control                            AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    Test Pending ACK                        AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Test Event Generate                     AccessMode.NA       Visibility.GURU          InterfaceType.COMMAND         -
#    Test Mode                               AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#   Transport Layer Control                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Payload Size                            AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         2764800
#    GigE Vision                             AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#     Physical Link Configuration             AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     SingleLink
#     Current Physical Link Configuration     AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     SingleLink
#     Supported Option Selector               AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     SingleLink
#     Supported Option                        AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#     Interface Selector                      AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#     MAC Address                             AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         30853687300965
#     PAUSE Frame Reception                   AccessMode.NI       Visibility.EXPERT        InterfaceType.BOOLEAN         -
#     PAUSE Frame Transmission                AccessMode.NI       Visibility.EXPERT        InterfaceType.BOOLEAN         -
#     Current IP Configuration LLA            AccessMode.RO       Visibility.BEGINNER      InterfaceType.BOOLEAN         True
#     Current IP Configuration DHCP           AccessMode.RW       Visibility.BEGINNER      InterfaceType.BOOLEAN         True
#     Current IP Configuration Persistent IP  AccessMode.RW       Visibility.BEGINNER      InterfaceType.BOOLEAN         False
#     Current IP Address                      AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         3095068713
#     Current Subnet Mask                     AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         4294901760
#     Current Default Gateway                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         0
#     IP Configuration Status                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.ENUMERATION     ForceIP
#     Persistent IP Address                   AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#     Persistent Subnet Mask                  AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#     Persistent Default Gateway              AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#     Persistent ARP Conflict Detection EnableAccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         True
#     Discovery ACK Delay                     AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         20
#     GVCP Extended Status Codes Selector     AccessMode.NI       Visibility.GURU          InterfaceType.ENUMERATION     -
#     GVCP Extended Status Codes              AccessMode.NI       Visibility.GURU          InterfaceType.BOOLEAN         -
#     GVCP Pending ACK                        AccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         True
#     Primary Application Switchover Key      AccessMode.WO       Visibility.GURU          InterfaceType.INTEGER         -
#     GVSP Extended ID Mode                   AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#     CCP                                     AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     ControlAccess
#     Primary Application Socket              AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         49153
#     Primary Application IP Address          AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         3095068673
#     Message Channel Port Host Port          AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#     Message Channel Destination Address     AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#     Message Channel Transmission Timeout    AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#     Message Channel Retry Count             AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#     Message Channel Source Port             AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         49153
#     Stream Channel Selector                 AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#     Stream Channel Port Interface Index     AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#     Stream Channel Port Host Port           AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#     Stream Channel Packet Size Fire Test PacketAccessMode.RO       Visibility.GURU          InterfaceType.BOOLEAN         False
#     Stream Channel Packet Size Do Not FragmentAccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         True
#     Stream Channel Packet Size Packet Size  AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         9000
#     Stream Channel Packet Delay             AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         80
#     Stream Channel Destination Address      AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         3095068673
#     Stream Channel Source Port              AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         49154
#     Stream Channel Frame Transmission Delay AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    PTP Control                             AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#     PTP Enable                              AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#     PTP Status                              AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Disabled
#     PTP Slave Only                          AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#     PTP Clock Accuracy                      AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     GreaterThan10s
#     PTP Servo Status                        AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Disabled
#     PTP Timestamp                           AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         14365507930752
#     PTP Timestamp Latch                     AccessMode.WO       Visibility.EXPERT        InterfaceType.COMMAND         -
#     PTP Timestamp Latch Value               AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#     PTP Offset From Master                  AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#     PTP Clock ID                            AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#     PTP Parent Clock ID                     AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#     PTP Grandmaster Clock ID                AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Received Packet Resend Count            AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         433
#    Valid Packet Resend Count               AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         80
#    Unavailable Packet Resend Count         AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         353
#   File Access Control                     AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    File Selector                           AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     UserSetDefault
#    File Operation Selector                 AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Open
#    File Operation Execute                  AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    File Open Mode                          AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Read
#    File Access Buffer                      AccessMode.RW       Visibility.GURU          InterfaceType.REGISTER        -
#    File Access Offset                      AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#    File Access Length                      AccessMode.NA       Visibility.GURU          InterfaceType.INTEGER         -
#    File Operation Status                   AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     None
#    File Operation Result                   AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    File Size                               AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         7700
#    File Storage Size                       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         16580608
#    File Storage Used Size                  AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         4923392
#    File Storage Free Size                  AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         11649024
#   Digital IO Control                      AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Line Selector                           AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Line0
#    Line Mode                               AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Input
#    Line Inverter                           AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Line Status                             AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Line Status All                         AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         12
#    Line Source                             AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Line Format                             AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     OptoCoupled
#    Line Filter Selector                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Deglitch
#    Line Filter Width                       AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           0.02
#    Voltage External Enable                 AccessMode.NA       Visibility.EXPERT        InterfaceType.BOOLEAN         -
#    User Output Selector                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     UserOutput0
#    User Output Value                       AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    User Output Value All                   AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#    User Output Value All Mask              AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#   Transfer Control                        AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Transfer Selector                       AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Stream0
#    Transfer Control Mode                   AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Basic
#    Transfer Operation Mode                 AccessMode.NA       Visibility.EXPERT        InterfaceType.ENUMERATION     -
#    Transfer Block Count                    AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Transfer Queue Max Block Count          AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Transfer Queue Current Block Count      AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Transfer Queue Mode                     AccessMode.NA       Visibility.EXPERT        InterfaceType.ENUMERATION     -
#    Transfer Start                          AccessMode.NA       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Transfer Stop                           AccessMode.NA       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Transfer Abort                          AccessMode.NA       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Transfer Pause                          AccessMode.NA       Visibility.GURU          InterfaceType.COMMAND         -
#    Transfer Resume                         AccessMode.NA       Visibility.GURU          InterfaceType.COMMAND         -
#    Transfer Status Selector                AccessMode.NA       Visibility.GURU          InterfaceType.ENUMERATION     -
#    Transfer Status                         AccessMode.NA       Visibility.GURU          InterfaceType.BOOLEAN         -
#   Serial Access Control                   AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    Serial Operation Selector               AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Read
#    Serial Operation Execute                AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Serial Access Buffer                    AccessMode.RW       Visibility.GURU          InterfaceType.REGISTER        -
#    Serial Access Length                    AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Serial Operation Status                 AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     None
#    Serial Operation Result                 AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    Serial Received Size                    AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    Serial Receive Source                   AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Off
#    Serial Baud Rate                        AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Baud57600
#    Serial Parity                           AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     None
#    Serial Stop Bits                        AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     StopBits1
#    Serial Data Bits                        AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     DataBits8
#    Serial Flow Control                     AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     None
#   Action Control                          AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    Action Unconditional Mode               AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Off
#    Action Queue Size                       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         4
#    Action Device Key                       AccessMode.WO       Visibility.GURU          InterfaceType.INTEGER         -
#    Action Selector                         AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Action Group Key                        AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Action Group Mask                       AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#   I2C Access Control                      AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    I2C Operation Selector                  AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Read
#    I2C Operation Execute                   AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    I2C Access Buffer                       AccessMode.RW       Visibility.GURU          InterfaceType.REGISTER        -
#    I2C Register Address                    AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    I2C Register Address Length             AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Bits8
#    I2C Access Length                       AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    I2C Operation Status                    AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     None
#    I2C Operation Result                    AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         0
#    I2C Slave Device Address                AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    I2C Slave Device Address Length         AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Bits7
#    I2C SCL Source                          AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Off
#    I2C SDA Source                          AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Off
#   Sequencer Control                       AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Sequencer Mode                          AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Sequencer Configuration Mode            AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Sequencer Feature Selector              AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     ExposureTime
#    Sequencer Feature Enable                AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#    Sequencer Set Selector                  AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Sequencer Set Save                      AccessMode.NA       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Sequencer Set Load                      AccessMode.NA       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Sequencer Set Active                    AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Sequencer Set Start                     AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Sequencer Path Selector                 AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Sequencer Set Next                      AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Sequencer Trigger Source                AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Sequencer Trigger Activation            AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     RisingEdge
#   Counter And Timer Control               AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Counter Selector                        AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Counter0
#    Counter Event Source                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Counter Event Activation                AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     RisingEdge
#    Counter Trigger Source                  AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Counter Trigger Activation              AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     RisingEdge
#    Counter Reset Source                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Counter Reset Activation                AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     RisingEdge
#    Counter Reset                           AccessMode.WO       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Counter Value                           AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Counter Value At Reset                  AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Counter Duration                        AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Counter Status                          AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     CounterIdle
#    Timer Selector                          AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Timer0
#    Timer Trigger Source                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Off
#    Timer Trigger Activation                AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     RisingEdge
#    Timer Duration                          AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           1.0
#    Timer Delay                             AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           0.0
#    Timer Reset                             AccessMode.WO       Visibility.EXPERT        InterfaceType.COMMAND         -
#    Timer Value                             AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           0.0
#    Timer Status                            AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     TimerIdle
#   Software Signal Control                 AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Software Signal Selector                AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     SoftwareSignal0
#    Software Signal Pulse                   AccessMode.WO       Visibility.BEGINNER      InterfaceType.COMMAND         -
#   Image Format Control                    AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Pixel Format                            AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     RGB8
#    Pixel Format Mapping Selector           AccessMode.NI       Visibility.GURU          InterfaceType.ENUMERATION     -
#    Pixel Format Mapping Enable             AccessMode.NI       Visibility.GURU          InterfaceType.BOOLEAN         -
#    Pixel Color Filter                      AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     None
#    ISP Bayer Pattern                       AccessMode.RO       Visibility.GURU          InterfaceType.ENUMERATION     RGGB
#    Sensor Width                            AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         2448
#    Sensor Height                           AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         2048
#    Shutter Mode                            AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     Global
#    Width Max                               AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         2448
#    Height Max                              AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         2048
#    Physical Pixel Size                     AccessMode.RO       Visibility.EXPERT        InterfaceType.FLOAT           3.45
#    ADC Bit Depth                           AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Bits12
#    Imager Width                            AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         1280
#    Imager Height                           AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         720
#    Imager Offset X                         AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Imager Offset Y                         AccessMode.RO       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Width                                   AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         1280
#    Height                                  AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         720
#    Offset X                                AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Offset Y                                AccessMode.RW       Visibility.BEGINNER      InterfaceType.INTEGER         0
#    Pixel Size                              AccessMode.RO       Visibility.EXPERT        InterfaceType.ENUMERATION     Bpp24
#    ReverseX                                AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    ReverseY                                AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Pixel Dynamic Range Min                 AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         0
#    Pixel Dynamic Range Max                 AccessMode.RO       Visibility.EXPERT        InterfaceType.INTEGER         255
#    Binning Selector                        AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Digital
#    Binning Horizontal Mode                 AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Sum
#    Binning Vertical Mode                   AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Sum
#    Binning Horizontal                      AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Binning Vertical                        AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Decimation Selector                     AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Sensor
#    Decimation Horizontal Mode              AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Discard
#    Decimation Vertical Mode                AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Discard
#    Decimation Horizontal                   AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Decimation Vertical                     AccessMode.RW       Visibility.EXPERT        InterfaceType.INTEGER         1
#    Test Pattern                            AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Off
#   Analog Control                          AccessMode.RO       Visibility.BEGINNER      InterfaceType.CATEGORY        -
#    Gain Selector                           AccessMode.RO       Visibility.BEGINNER      InterfaceType.ENUMERATION     All
#    Gain                                    AccessMode.RW       Visibility.BEGINNER      InterfaceType.FLOAT           0.0
#    Gain Raw                                AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Gain Auto                               AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Off
#    Gain Auto Lower Limit                   AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           0.0
#    Gain Auto Upper Limit                   AccessMode.RO       Visibility.BEGINNER      InterfaceType.FLOAT           48.0
#    Black Level Selector                    AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     All
#    Black Level                             AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           0.0
#    Black Level Raw                         AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Balance Ratio Selector                  AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Red
#    Balance Ratio                           AccessMode.RO       Visibility.EXPERT        InterfaceType.FLOAT           1.825927734375
#    Balance White Auto                      AccessMode.RW       Visibility.BEGINNER      InterfaceType.ENUMERATION     Continuous
#    Balance White Enable                    AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#    BalanceWhiteAuto Anchor Selector        AccessMode.RW       Visibility.GURU          InterfaceType.ENUMERATION     MaxRGB
#    AWB White Patch Enable                  AccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         True
#    AWB Stats Frame Count                   AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         1
#    AWB Bayer Pattern                       AccessMode.RO       Visibility.INVISIBLE     InterfaceType.ENUMERATION     RGGB
#    Gamma Enable                            AccessMode.RW       Visibility.BEGINNER      InterfaceType.BOOLEAN         True
#    Gamma                                   AccessMode.RW       Visibility.BEGINNER      InterfaceType.FLOAT           1.0
#    Gamma Raw                               AccessMode.RW       Visibility.INVISIBLE     InterfaceType.INTEGER         256
#   Color Transformation Control            AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Color Transformation Enable             AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#    Color Transformation Selector           AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     RGBtoRGB
#    Color Transformation Value Selector     AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Gain00
#    Color Transformation Value              AccessMode.RW       Visibility.EXPERT        InterfaceType.FLOAT           1.59033203125
#   LUT Control                             AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    LUT Enable                              AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    LUT Selector                            AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Luminance
#    LUT Index                               AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    LUT Value                               AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    LUT Value All                           AccessMode.RW       Visibility.GURU          InterfaceType.REGISTER        -
#    LUT Save                                AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    LUT Set Default                         AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#   Defect Correction Control               AccessMode.RO       Visibility.GURU          InterfaceType.CATEGORY        -
#    Defect Correction Enable                AccessMode.RW       Visibility.GURU          InterfaceType.BOOLEAN         True
#    Defect Correction Count                 AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         1
#    Defect Correction Index                 AccessMode.RW       Visibility.GURU          InterfaceType.INTEGER         0
#    Defect Position X                       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         256
#    Defect Position Y                       AccessMode.RO       Visibility.GURU          InterfaceType.INTEGER         128
#    Defect Correction Get New Defect        AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Defect Correction Apply                 AccessMode.NA       Visibility.GURU          InterfaceType.COMMAND         -
#    Defect Correction Remove                AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Defect Correction Save                  AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#    Defect Correction Restore Default       AccessMode.WO       Visibility.GURU          InterfaceType.COMMAND         -
#   Chunk Data Control                      AccessMode.RO       Visibility.EXPERT        InterfaceType.CATEGORY        -
#    Chunk Mode Active                       AccessMode.RW       Visibility.EXPERT        InterfaceType.BOOLEAN         False
#    Chunk Selector                          AccessMode.RW       Visibility.EXPERT        InterfaceType.ENUMERATION     Image
#    Chunk Enable                            AccessMode.RO       Visibility.EXPERT        InterfaceType.BOOLEAN         True
#    Chunk CRC                               AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Pixel Format                      AccessMode.NA       Visibility.EXPERT        InterfaceType.ENUMERATION     -
#    Chunk Width                             AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Height                            AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Offset X                          AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Offset Y                          AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Pixel Dynamic Range Min           AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Pixel Dynamic Range Max           AccessMode.NA       Visibility.EXPERT        InterfaceType.INTEGER         -
#    Chunk Gain                              AccessMode.NA       Visibility.EXPERT        InterfaceType.FLOAT           -
#    Chunk Black Level                       AccessMode.NA       Visibility.EXPERT        InterfaceType.FLOAT           -
#    Chunk Exposure Time                     AccessMode.NA       Visibility.EXPERT        InterfaceType.FLOAT           -
#
# Device destroyed
# Example Finished
